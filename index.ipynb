# %% [markdown]
# # Nearest Neighbors Lab

# %% [markdown]
# ### Introduction
#
# In this lab, you apply nearest neighbors technique to help a taxi company predict the length of their rides.  Imagine that we are hired to consult for LiftOff, a limo and taxi service that is just opening up in NYC.  Liftoff wants it's taxi drivers to target longer rides, as the longer the ride the more money it makes.  LiftOff has the following theory:
#
# * the pickup location of a taxi ride can help predict the length of the ride.
#
#
#
# LiftOff asks us to do some analysis to write a function that will allow it to **predict the length of a taxi ride for any given location **.
#
# Our technique will be the following:
#   * **Collect** Obtain the data containing all of the taxi information, and only select the attributes of taxi trips that we need
#   * ** Explore ** Examine the attributes of our data, and plot some of our data on a map
#   * ** Train ** Write our nearest neighbors formula, and change the number of nearby trips to predict the length of a new trip
#   * ** Predict ** Use our function to predict trip lengths of new locations

# %% [markdown]
# ### Collect and Explore the data

# %% [markdown]
# #### Collect the Data

# %% [markdown]
# Luckily for us, [NYC Open Data](https://opendata.cityofnewyork.us/) collects information about NYC taxi trips and provides this data on [its website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n).

# %% [markdown]
# ![](./nyc-taxi.png)

# %% [markdown]
# For your reading pleasure, the data has already been downloaded into the [trips.json](https://github.com/learn-co-curriculum/nearest-neighbors-lab/blob/master/trips.json) file in this lab which you can find here.  We'll use Python's `json` library to take the data from the `trips.json` file and store it as a variable in our notebook.

# %%
import pandas

def parse_file(fileName):
    trips_df = pandas.read_json(fileName)
    return trips_df.to_dict('records')

trips = parse_file('trips.json')

# %% [markdown]
# > Press shift + enter

# %% [markdown]
# #### Explore the data

# %% [markdown]
# The next step is to explore the data.  First, let's see how many trips we have.

# %%
len(trips)
# Out:
# 1000

# %% [markdown]
# Not bad at all.  Now let's see what each individual trip looks like.  Each trip is a dictionary, so we can see the attributes of each trip with the `keys` function.

# %%
trips
# Out:
# [{'dropoff_datetime': '2014-11-26T22:31:00.000',
#   'dropoff_latitude': 40.74677,
#   'dropoff_longitude': -73.99745,
#   'fare_amount': 52.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-26T21:59:00.000',
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'rate_code': 2,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 5.33,
#   'total_amount': 57.83,
#   'trip_distance': 18.38,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-22T17:54:37.000',
#   'dropoff_latitude': 40.781845,
#   'dropoff_longitude': -73.979073,
#   'fare_amount': 7.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-22T17:47:23.000',
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.0,
#   'trip_distance': 1.3,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-06T04:07:34.000',
#   'dropoff_latitude': 40.72661,
#   'dropoff_longitude': -73.995955,
#   'fare_amount': 15.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-06T03:51:59.000',
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 3.3,
#   'tolls_amount': 0.0,
#   'total_amount': 19.8,
#   'trip_distance': 4.5,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-08T21:15:30.000',
#   'dropoff_latitude': 40.773373,
#   'dropoff_longitude': -73.949354,
#   'fare_amount': 11.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-09-08T21:02:17.000',
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 12.5,
#   'trip_distance': 2.4,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-13T11:55:00.000',
#   'dropoff_latitude': 40.752932,
#   'dropoff_longitude': -73.974688,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-11-13T11:50:00.000',
#   'pickup_latitude': 40.762912,
#   'pickup_longitude': -73.967782,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.1,
#   'tolls_amount': 0.0,
#   'total_amount': 7.1,
#   'trip_distance': 0.84,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-25T19:15:41.000',
#   'dropoff_latitude': 40.739657,
#   'dropoff_longitude': -73.99635,
#   'fare_amount': 6.0,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-25T19:08:59.000',
#   'pickup_latitude': 40.731176,
#   'pickup_longitude': -73.991572,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'Y',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.5,
#   'trip_distance': 0.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-27T04:53:20.000',
#   'dropoff_latitude': 40.802212,
#   'dropoff_longitude': -73.961762,
#   'fare_amount': 4.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-27T04:50:41.000',
#   'pickup_latitude': 40.800219,
#   'pickup_longitude': -73.968098,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 5.0,
#   'trip_distance': 0.5,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-21T21:02:31.000',
#   'dropoff_latitude': 40.735434,
#   'dropoff_longitude': -73.977671,
#   'fare_amount': 52.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-21T20:18:41.000',
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'rate_code': 2,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 8.0,
#   'tolls_amount': 5.33,
#   'total_amount': 65.83,
#   'trip_distance': 17.3,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-10T17:26:00.000',
#   'dropoff_latitude': 40.727227,
#   'dropoff_longitude': -73.976853,
#   'fare_amount': 4.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-10T17:23:00.000',
#   'pickup_latitude': 40.721897,
#   'pickup_longitude': -73.983493,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.0,
#   'trip_distance': 0.63,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-09-30T23:32:03.000',
#   'dropoff_latitude': 40.820474,
#   'dropoff_longitude': -73.944074,
#   'fare_amount': 11.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-30T23:20:30.000',
#   'pickup_latitude': 40.791566,
#   'pickup_longitude': -73.972224,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 3.1,
#   'tolls_amount': 0.0,
#   'total_amount': 15.6,
#   'trip_distance': 2.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-15T13:10:05.000',
#   'dropoff_latitude': 40.751105,
#   'dropoff_longitude': -73.972253,
#   'fare_amount': 6.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-15T13:02:36.000',
#   'pickup_latitude': 40.744896,
#   'pickup_longitude': -73.978619,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.4,
#   'tolls_amount': 0.0,
#   'total_amount': 8.4,
#   'trip_distance': 0.6,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-20T02:40:46.000',
#   'dropoff_latitude': 40.733991,
#   'dropoff_longitude': -73.854062,
#   'fare_amount': 7.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-20T02:34:03.000',
#   'pickup_latitude': 40.721951,
#   'pickup_longitude': -73.844435,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.6,
#   'tolls_amount': 0.0,
#   'total_amount': 9.6,
#   'trip_distance': 1.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2015-01-01T00:04:04.000',
#   'dropoff_latitude': 40.722156,
#   'dropoff_longitude': -73.957714,
#   'fare_amount': 17.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-31T23:43:45.000',
#   'pickup_latitude': 40.732382,
#   'pickup_longitude': -74.001682,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 2.0,
#   'tolls_amount': 0.0,
#   'total_amount': 20.0,
#   'trip_distance': 4.2,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-15T12:55:37.000',
#   'dropoff_latitude': 40.773613,
#   'dropoff_longitude': -73.959655,
#   'fare_amount': 4.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-09-15T12:52:52.000',
#   'pickup_latitude': 40.768339,
#   'pickup_longitude': -73.961478,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 4.5,
#   'trip_distance': 0.4,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-07T10:02:49.000',
#   'dropoff_latitude': 40.769261,
#   'dropoff_longitude': -73.963158,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-07T09:57:23.000',
#   'pickup_latitude': 40.775933,
#   'pickup_longitude': -73.962446,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.0,
#   'trip_distance': 0.6,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-07-19T07:08:16.000',
#   'dropoff_latitude': 40.770346,
#   'dropoff_longitude': -73.864904,
#   'fare_amount': 29.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-07-19T06:45:15.000',
#   'pickup_latitude': 40.794829,
#   'pickup_longitude': -73.971476,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 5.33,
#   'total_amount': 35.33,
#   'trip_distance': 9.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-19T23:53:00.000',
#   'dropoff_latitude': 40.76919,
#   'dropoff_longitude': -73.955032,
#   'fare_amount': 5.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-19T23:50:00.000',
#   'pickup_latitude': 40.758647,
#   'pickup_longitude': -73.964878,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.0,
#   'trip_distance': 1.05,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-31T09:36:00.000',
#   'dropoff_latitude': 40.720817,
#   'dropoff_longitude': -74.010177,
#   'fare_amount': 5.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-31T09:32:00.000',
#   'pickup_latitude': 40.713638,
#   'pickup_longitude': -74.011587,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.5,
#   'trip_distance': 0.74,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-24T18:51:40.000',
#   'dropoff_latitude': 40.750018,
#   'dropoff_longitude': -73.98608,
#   'fare_amount': 26.0,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-24T18:30:51.000',
#   'pickup_latitude': 40.77403,
#   'pickup_longitude': -73.874597,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 8.2,
#   'tolls_amount': 5.33,
#   'total_amount': 41.03,
#   'trip_distance': 8.4,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-09T23:55:17.000',
#   'dropoff_latitude': 40.780655,
#   'dropoff_longitude': -73.950056,
#   'fare_amount': 21.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-09T23:28:24.000',
#   'pickup_latitude': 40.728127,
#   'pickup_longitude': -73.99887,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 3.0,
#   'tolls_amount': 0.0,
#   'total_amount': 25.5,
#   'trip_distance': 5.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-06T16:12:01.000',
#   'dropoff_latitude': 40.777823,
#   'dropoff_longitude': -73.960833,
#   'fare_amount': 7.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-06T16:04:23.000',
#   'pickup_latitude': 40.759671,
#   'pickup_longitude': -73.976688,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.8,
#   'tolls_amount': 0.0,
#   'total_amount': 10.8,
#   'trip_distance': 1.4,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-12-23T15:37:25.000',
#   'dropoff_latitude': 40.744025,
#   'dropoff_longitude': -73.995136,
#   'fare_amount': 18.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-23T15:09:38.000',
#   'pickup_latitude': 40.772651,
#   'pickup_longitude': -73.967095,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 4.6,
#   'tolls_amount': 0.0,
#   'total_amount': 23.1,
#   'trip_distance': 2.7,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-09T12:19:26.000',
#   'dropoff_latitude': 40.780225,
#   'dropoff_longitude': -73.955196,
#   'fare_amount': 4.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-09T12:16:48.000',
#   'pickup_latitude': 40.770319,
#   'pickup_longitude': -73.960222,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.0,
#   'trip_distance': 0.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-08T12:25:00.000',
#   'dropoff_latitude': 40.713932,
#   'dropoff_longitude': -73.991835,
#   'fare_amount': 7.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-08T12:14:00.000',
#   'pickup_latitude': 40.720457,
#   'pickup_longitude': -73.988065,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.5,
#   'trip_distance': 1.12,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-08T01:35:17.000',
#   'dropoff_latitude': 40.841256,
#   'dropoff_longitude': -73.783576,
#   'fare_amount': 44.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-10-08T01:06:04.000',
#   'pickup_latitude': 40.754789,
#   'pickup_longitude': -73.973606,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 45.0,
#   'trip_distance': 16.0,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-10T14:11:53.000',
#   'dropoff_latitude': 40.741031,
#   'dropoff_longitude': -73.983575,
#   'fare_amount': 8.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-10T14:01:05.000',
#   'pickup_latitude': 40.755654,
#   'pickup_longitude': -73.985846,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 9.0,
#   'trip_distance': 1.4,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-29T18:24:50.000',
#   'dropoff_latitude': 40.746359,
#   'dropoff_longitude': -73.994102,
#   'fare_amount': 7.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-29T18:15:44.000',
#   'pickup_latitude': 40.741568,
#   'pickup_longitude': -73.978341,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 9.0,
#   'trip_distance': 0.9,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-27T17:18:00.000',
#   'dropoff_latitude': 40.737297,
#   'dropoff_longitude': -73.996297,
#   'fare_amount': 6.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-10-27T17:10:00.000',
#   'pickup_latitude': 40.736907,
#   'pickup_longitude': -73.98862,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.0,
#   'trip_distance': 0.74,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-21T07:28:22.000',
#   'dropoff_latitude': 40.75479,
#   'dropoff_longitude': -73.984453,
#   'fare_amount': 8.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-21T07:19:24.000',
#   'pickup_latitude': 40.76003,
#   'pickup_longitude': -73.964842,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.7,
#   'tolls_amount': 0.0,
#   'total_amount': 10.2,
#   'trip_distance': 1.5,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-06T14:52:54.000',
#   'dropoff_latitude': 40.729245,
#   'dropoff_longitude': -74.002259,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-06T14:47:54.000',
#   'pickup_latitude': 40.721366,
#   'pickup_longitude': -74.008287,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.0,
#   'trip_distance': 0.7,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-11T23:16:00.000',
#   'dropoff_latitude': 40.75615,
#   'dropoff_longitude': -74.002657,
#   'fare_amount': 10.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-11T23:04:00.000',
#   'pickup_latitude': 40.760147,
#   'pickup_longitude': -73.97627,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 11.0,
#   'trip_distance': 1.97,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-09-25T14:54:00.000',
#   'dropoff_latitude': 40.73659,
#   'dropoff_longitude': -74.001142,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-25T14:47:00.000',
#   'pickup_latitude': 40.745847,
#   'pickup_longitude': -74.001817,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.2,
#   'tolls_amount': 0.0,
#   'total_amount': 7.7,
#   'trip_distance': 0.96,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-06-19T12:11:00.000',
#   'dropoff_latitude': 40.758865,
#   'dropoff_longitude': -73.977012,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-19T12:04:00.000',
#   'pickup_latitude': 40.753015,
#   'pickup_longitude': -73.985247,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.5,
#   'trip_distance': 0.74,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-07T07:46:02.000',
#   'dropoff_latitude': 40.659523,
#   'dropoff_longitude': -73.949676,
#   'fare_amount': 42.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-07T07:00:25.000',
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 43.0,
#   'trip_distance': 12.7,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-06T16:23:00.000',
#   'dropoff_latitude': 40.738737,
#   'dropoff_longitude': -73.992067,
#   'fare_amount': 7.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-06T16:15:00.000',
#   'pickup_latitude': 40.738767,
#   'pickup_longitude': -74.0086,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.12,
#   'tolls_amount': 0.0,
#   'total_amount': 11.12,
#   'trip_distance': 1.17,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-19T13:17:54.000',
#   'dropoff_latitude': 40.771952,
#   'dropoff_longitude': -73.571903,
#   'fare_amount': 87.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-19T12:39:47.000',
#   'pickup_latitude': 40.773797,
#   'pickup_longitude': -73.871065,
#   'rate_code': 4,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 87.5,
#   'trip_distance': 22.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-16T13:33:05.000',
#   'dropoff_latitude': 40.734975,
#   'dropoff_longitude': -73.99444,
#   'fare_amount': 9.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-16T13:21:14.000',
#   'pickup_latitude': 40.743411,
#   'pickup_longitude': -73.97686,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 10.0,
#   'trip_distance': 1.5,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-26T18:07:48.000',
#   'dropoff_latitude': 40.741962,
#   'dropoff_longitude': -73.98078,
#   'fare_amount': 10.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-26T17:53:16.000',
#   'pickup_latitude': 40.758905,
#   'pickup_longitude': -73.967897,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 2.4,
#   'tolls_amount': 0.0,
#   'total_amount': 14.4,
#   'trip_distance': 1.5,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-24T18:01:00.000',
#   'dropoff_latitude': 40.736397,
#   'dropoff_longitude': -74.008317,
#   'fare_amount': 11.0,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-24T17:46:00.000',
#   'pickup_latitude': 40.733877,
#   'pickup_longitude': -73.989602,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.4,
#   'tolls_amount': 0.0,
#   'total_amount': 14.9,
#   'trip_distance': 1.7,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-01-08T20:48:00.000',
#   'dropoff_latitude': 40.71465,
#   'dropoff_longitude': -73.99108,
#   'fare_amount': 6.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-01-08T20:40:00.000',
#   'pickup_latitude': 40.726162,
#   'pickup_longitude': -73.983432,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.5,
#   'trip_distance': 0.95,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-18T13:53:00.000',
#   'dropoff_latitude': 40.72627,
#   'dropoff_longitude': -73.999298,
#   'fare_amount': 20.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-18T13:36:00.000',
#   'pickup_latitude': 40.775122,
#   'pickup_longitude': -73.947765,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.5,
#   'tolls_amount': 0.0,
#   'total_amount': 22.0,
#   'trip_distance': 5.88,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-29T23:54:16.000',
#   'dropoff_latitude': 40.75856,
#   'dropoff_longitude': -73.916076,
#   'fare_amount': 16.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-29T23:35:59.000',
#   'pickup_latitude': 40.75987,
#   'pickup_longitude': -73.978487,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 3.5,
#   'tolls_amount': 0.0,
#   'total_amount': 21.0,
#   'trip_distance': 4.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-11T18:36:00.000',
#   'dropoff_latitude': 40.721972,
#   'dropoff_longitude': -73.947227,
#   'fare_amount': 6.0,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-11T18:30:00.000',
#   'pickup_latitude': 40.707087,
#   'pickup_longitude': -73.94328,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.5,
#   'trip_distance': 1.09,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-04T19:24:00.000',
#   'dropoff_latitude': 40.728095,
#   'dropoff_longitude': -73.99457,
#   'fare_amount': 7.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-04T19:14:00.000',
#   'pickup_latitude': 40.741912,
#   'pickup_longitude': -74.003578,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.12,
#   'tolls_amount': 0.0,
#   'total_amount': 11.12,
#   'trip_distance': 1.39,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-25T17:41:05.000',
#   'dropoff_latitude': 40.697948,
#   'dropoff_longitude': -73.995544,
#   'fare_amount': 31.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-25T17:16:12.000',
#   'pickup_latitude': 40.769112,
#   'pickup_longitude': -73.862679,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 8.0,
#   'tolls_amount': 0.0,
#   'total_amount': 40.0,
#   'trip_distance': 11.2,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-27T22:33:00.000',
#   'dropoff_latitude': 40.762002,
#   'dropoff_longitude': -73.985797,
#   'fare_amount': 10.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-27T22:22:00.000',
#   'pickup_latitude': 40.785807,
#   'pickup_longitude': -73.976387,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.2,
#   'tolls_amount': 0.0,
#   'total_amount': 13.7,
#   'trip_distance': 2.56,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-07T20:28:00.000',
#   'dropoff_latitude': 40.756317,
#   'dropoff_longitude': -73.97488,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-07T20:22:00.000',
#   'pickup_latitude': 40.7513,
#   'pickup_longitude': -73.986852,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.0,
#   'trip_distance': 1.03,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-12-12T14:22:00.000',
#   'dropoff_latitude': 40.749845,
#   'dropoff_longitude': -73.975106,
#   'fare_amount': 11.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-12T14:04:53.000',
#   'pickup_latitude': 40.733385,
#   'pickup_longitude': -73.987204,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 13.0,
#   'trip_distance': 1.3,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-30T16:58:59.000',
#   'dropoff_latitude': 40.748457,
#   'dropoff_longitude': -73.984584,
#   'fare_amount': 5.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-30T16:54:27.000',
#   'pickup_latitude': 40.760257,
#   'pickup_longitude': -73.976186,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.4,
#   'tolls_amount': 0.0,
#   'total_amount': 8.4,
#   'trip_distance': 0.9,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-12-14T00:38:43.000',
#   'dropoff_latitude': 40.777341,
#   'dropoff_longitude': -73.982516,
#   'fare_amount': 17.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'NOC',
#   'pickup_datetime': '2014-12-14T00:15:19.000',
#   'pickup_latitude': 40.741249,
#   'pickup_longitude': -74.005201,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 18.0,
#   'trip_distance': 3.4,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-16T21:10:34.000',
#   'dropoff_latitude': 40.76093,
#   'dropoff_longitude': -73.998472,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-16T21:05:13.000',
#   'pickup_latitude': 40.759795,
#   'pickup_longitude': -73.985352,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.3,
#   'tolls_amount': 0.0,
#   'total_amount': 7.8,
#   'trip_distance': 0.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-11T19:09:07.000',
#   'dropoff_latitude': 40.751592,
#   'dropoff_longitude': -73.976827,
#   'fare_amount': 6.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-11T19:01:32.000',
#   'pickup_latitude': 40.756636,
#   'pickup_longitude': -73.9697,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 2.1,
#   'tolls_amount': 0.0,
#   'total_amount': 9.1,
#   'trip_distance': 0.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-11T16:14:08.000',
#   'dropoff_latitude': 40.744498,
#   'dropoff_longitude': -74.007935,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-11-11T16:08:26.000',
#   'pickup_latitude': 40.73925,
#   'pickup_longitude': -74.000759,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.2,
#   'tolls_amount': 0.0,
#   'total_amount': 7.2,
#   'trip_distance': 0.6,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-08T02:00:00.000',
#   'dropoff_latitude': 40.747732,
#   'dropoff_longitude': -73.989097,
#   'fare_amount': 6.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-08T01:53:00.000',
#   'pickup_latitude': 40.751055,
#   'pickup_longitude': -73.97607,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.5,
#   'trip_distance': 1.07,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-15T19:20:03.000',
#   'dropoff_latitude': 40.683392,
#   'dropoff_longitude': -73.99979,
#   'fare_amount': 17.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-15T18:57:37.000',
#   'pickup_latitude': 40.723584,
#   'pickup_longitude': -73.995992,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 18.0,
#   'trip_distance': 3.9,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-25T07:02:00.000',
#   'dropoff_latitude': 40.644307,
#   'dropoff_longitude': -73.790767,
#   'fare_amount': 39.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-25T06:43:00.000',
#   'pickup_latitude': 40.757037,
#   'pickup_longitude': -73.929485,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 39.5,
#   'trip_distance': 14.43,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-18T08:30:40.000',
#   'dropoff_latitude': 40.750043,
#   'dropoff_longitude': -73.979163,
#   'fare_amount': 5.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-18T08:25:55.000',
#   'pickup_latitude': 40.743385,
#   'pickup_longitude': -73.981978,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 5.5,
#   'trip_distance': 0.6,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-04T15:31:57.000',
#   'dropoff_latitude': 40.761551,
#   'dropoff_longitude': -73.97007,
#   'fare_amount': 8.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-10-04T15:23:55.000',
#   'pickup_latitude': 40.737486,
#   'pickup_longitude': -73.978153,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 9.0,
#   'trip_distance': 2.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-26T13:16:00.000',
#   'dropoff_latitude': 40.76303,
#   'dropoff_longitude': -73.97377,
#   'fare_amount': 8.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-26T13:08:00.000',
#   'pickup_latitude': 40.77225,
#   'pickup_longitude': -73.95285,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.12,
#   'tolls_amount': 0.0,
#   'total_amount': 11.12,
#   'trip_distance': 1.76,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-07-01T18:39:00.000',
#   'dropoff_latitude': 40.706077,
#   'dropoff_longitude': -74.006857,
#   'fare_amount': 11.0,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-07-01T18:27:00.000',
#   'pickup_latitude': 40.732882,
#   'pickup_longitude': -73.981975,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.4,
#   'tolls_amount': 0.0,
#   'total_amount': 14.9,
#   'trip_distance': 2.45,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-06T19:18:00.000',
#   'dropoff_latitude': 40.799965,
#   'dropoff_longitude': -73.969547,
#   'fare_amount': 8.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-06T19:10:00.000',
#   'pickup_latitude': 40.774567,
#   'pickup_longitude': -73.988232,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.38,
#   'tolls_amount': 0.0,
#   'total_amount': 12.38,
#   'trip_distance': 2.03,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-11T17:57:00.000',
#   'dropoff_latitude': 40.753735,
#   'dropoff_longitude': -73.974355,
#   'fare_amount': 6.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-11T17:49:00.000',
#   'pickup_latitude': 40.757437,
#   'pickup_longitude': -73.964735,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.0,
#   'trip_distance': 0.8,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-09T13:03:00.000',
#   'dropoff_latitude': 40.796772,
#   'dropoff_longitude': -73.948922,
#   'fare_amount': 10.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-09T12:52:00.000',
#   'pickup_latitude': 40.789637,
#   'pickup_longitude': -73.975402,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.0,
#   'tolls_amount': 0.0,
#   'total_amount': 12.5,
#   'trip_distance': 2.14,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-26T11:36:37.000',
#   'dropoff_latitude': 40.740513,
#   'dropoff_longitude': -73.99258,
#   'fare_amount': 10.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-26T11:22:53.000',
#   'pickup_latitude': 40.754317,
#   'pickup_longitude': -73.992548,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 2.1,
#   'tolls_amount': 0.0,
#   'total_amount': 12.6,
#   'trip_distance': 1.3,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-14T11:00:00.000',
#   'dropoff_latitude': 40.750145,
#   'dropoff_longitude': -73.99491,
#   'fare_amount': 6.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-14T10:52:00.000',
#   'pickup_latitude': 40.745007,
#   'pickup_longitude': -73.998627,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.3,
#   'tolls_amount': 0.0,
#   'total_amount': 8.3,
#   'trip_distance': 0.44,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-12-19T21:10:00.000',
#   'dropoff_latitude': 40.72754,
#   'dropoff_longitude': -73.98241,
#   'fare_amount': 7.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-19T21:02:00.000',
#   'pickup_latitude': 40.734982,
#   'pickup_longitude': -73.990523,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.5,
#   'tolls_amount': 0.0,
#   'total_amount': 9.5,
#   'trip_distance': 1.0,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-03T13:48:00.000',
#   'dropoff_latitude': 0.0,
#   'dropoff_longitude': 0.0,
#   'fare_amount': 10.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-03T13:35:00.000',
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.5,
#   'tolls_amount': 0.0,
#   'total_amount': 13.0,
#   'trip_distance': 1.95,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-26T12:55:00.000',
#   'dropoff_latitude': 40.751157,
#   'dropoff_longitude': -73.9914,
#   'fare_amount': 8.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-26T12:46:00.000',
#   'pickup_latitude': 40.738617,
#   'pickup_longitude': -73.989672,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 9.0,
#   'trip_distance': 1.48,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-25T20:20:24.000',
#   'dropoff_latitude': 40.79709,
#   'dropoff_longitude': -73.968839,
#   'fare_amount': 3.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-25T20:19:07.000',
#   'pickup_latitude': 40.790712,
#   'pickup_longitude': -73.972809,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 4.5,
#   'trip_distance': 0.5,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-08-09T11:58:30.000',
#   'dropoff_latitude': 40.763726,
#   'dropoff_longitude': -73.971545,
#   'fare_amount': 7.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-09T11:51:20.000',
#   'pickup_latitude': 40.750167,
#   'pickup_longitude': -73.987398,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.0,
#   'trip_distance': 1.5,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-07-24T14:08:04.000',
#   'dropoff_latitude': 40.597785,
#   'dropoff_longitude': -73.966445,
#   'fare_amount': 38.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-07-24T13:34:18.000',
#   'pickup_latitude': 40.732141,
#   'pickup_longitude': -73.98447,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 39.0,
#   'trip_distance': 12.7,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-13T15:01:59.000',
#   'dropoff_latitude': 40.75168,
#   'dropoff_longitude': -74.005762,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-13T14:57:46.000',
#   'pickup_latitude': 40.765758,
#   'pickup_longitude': -73.994847,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.2,
#   'tolls_amount': 0.0,
#   'total_amount': 7.2,
#   'trip_distance': 1.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-11T16:56:25.000',
#   'dropoff_latitude': 40.785751,
#   'dropoff_longitude': -73.976722,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 4,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-11T16:50:24.000',
#   'pickup_latitude': 40.792594,
#   'pickup_longitude': -73.964102,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 2.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.5,
#   'trip_distance': 1.0,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-27T20:25:44.000',
#   'dropoff_latitude': 40.749738,
#   'dropoff_longitude': -73.987525,
#   'fare_amount': 9.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-27T20:15:58.000',
#   'pickup_latitude': 40.762908,
#   'pickup_longitude': -73.969549,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 10.0,
#   'trip_distance': 1.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-08-15T16:36:00.000',
#   'dropoff_latitude': 40.803005,
#   'dropoff_longitude': -73.963775,
#   'fare_amount': 20.0,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-15T16:09:00.000',
#   'pickup_latitude': 40.750722,
#   'pickup_longitude': -73.968447,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 4.2,
#   'tolls_amount': 0.0,
#   'total_amount': 25.7,
#   'trip_distance': 4.85,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-16T18:43:00.000',
#   'dropoff_latitude': 40.722627,
#   'dropoff_longitude': -73.840562,
#   'fare_amount': 16.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-16T18:30:00.000',
#   'pickup_latitude': 40.769887,
#   'pickup_longitude': -73.86443,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 17.0,
#   'trip_distance': 5.09,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-13T02:50:55.000',
#   'dropoff_latitude': 40.781951,
#   'dropoff_longitude': -73.979131,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-13T02:47:01.000',
#   'pickup_latitude': 40.77247,
#   'pickup_longitude': -73.982419,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.0,
#   'trip_distance': 1.2,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-27T03:08:00.000',
#   'dropoff_latitude': 40.776617,
#   'dropoff_longitude': -73.989395,
#   'fare_amount': 7.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 6,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-27T03:01:00.000',
#   'pickup_latitude': 40.764545,
#   'pickup_longitude': -73.982668,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.6,
#   'tolls_amount': 0.0,
#   'total_amount': 10.1,
#   'trip_distance': 1.44,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-18T13:02:00.000',
#   'dropoff_latitude': 40.750025,
#   'dropoff_longitude': -73.978203,
#   'fare_amount': 52.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-11-18T12:11:00.000',
#   'pickup_latitude': 40.641805,
#   'pickup_longitude': -73.78641,
#   'rate_code': 2,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 11.47,
#   'tolls_amount': 5.33,
#   'total_amount': 69.3,
#   'trip_distance': 16.63,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-07-01T10:46:00.000',
#   'dropoff_latitude': 40.752117,
#   'dropoff_longitude': -73.98684,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-07-01T10:40:00.000',
#   'pickup_latitude': 40.75224,
#   'pickup_longitude': -73.97835,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.1,
#   'tolls_amount': 0.0,
#   'total_amount': 7.1,
#   'trip_distance': 0.79,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-26T17:06:00.000',
#   'dropoff_latitude': 40.75015,
#   'dropoff_longitude': -73.994875,
#   'fare_amount': 11.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-26T16:50:00.000',
#   'pickup_latitude': 40.758835,
#   'pickup_longitude': -73.988555,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 11.5,
#   'trip_distance': 1.36,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-23T07:49:00.000',
#   'dropoff_latitude': 40.746622,
#   'dropoff_longitude': -73.971385,
#   'fare_amount': 8.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-23T07:43:00.000',
#   'pickup_latitude': 40.722785,
#   'pickup_longitude': -73.988558,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.5,
#   'trip_distance': 2.04,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-24T19:44:06.000',
#   'dropoff_latitude': 40.73201,
#   'dropoff_longitude': -73.993964,
#   'fare_amount': 6.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-24T19:36:48.000',
#   'pickup_latitude': 40.720338,
#   'pickup_longitude': -73.993645,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 2.0,
#   'tolls_amount': 0.0,
#   'total_amount': 10.0,
#   'trip_distance': 0.9,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-27T21:24:00.000',
#   'dropoff_latitude': 40.744887,
#   'dropoff_longitude': -74.00152,
#   'fare_amount': 8.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 6,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-27T21:15:00.000',
#   'pickup_latitude': 40.72973,
#   'pickup_longitude': -73.991628,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.7,
#   'tolls_amount': 0.0,
#   'total_amount': 10.7,
#   'trip_distance': 1.65,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-02T10:55:00.000',
#   'dropoff_latitude': 40.760462,
#   'dropoff_longitude': -73.967142,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 3,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-02T10:49:00.000',
#   'pickup_latitude': 40.760442,
#   'pickup_longitude': -73.958405,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.5,
#   'trip_distance': 0.64,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-12T14:43:00.000',
#   'dropoff_latitude': 40.742352,
#   'dropoff_longitude': -73.988957,
#   'fare_amount': 8.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-12T14:34:00.000',
#   'pickup_latitude': 40.756227,
#   'pickup_longitude': -73.98314,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.5,
#   'trip_distance': 1.34,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-26T09:14:00.000',
#   'dropoff_latitude': 40.756347,
#   'dropoff_longitude': -73.980583,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-26T09:09:00.000',
#   'pickup_latitude': 40.751555,
#   'pickup_longitude': -73.992905,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.5,
#   'trip_distance': 1.13,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-29T17:57:15.000',
#   'dropoff_latitude': 40.72597,
#   'dropoff_longitude': -73.986544,
#   'fare_amount': 7.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-11-29T17:49:16.000',
#   'pickup_latitude': 40.71333,
#   'pickup_longitude': -74.004106,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 3.0,
#   'tolls_amount': 0.0,
#   'total_amount': 11.0,
#   'trip_distance': 1.3,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-15T22:27:22.000',
#   'dropoff_latitude': 40.778295,
#   'dropoff_longitude': -73.981824,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-15T22:23:44.000',
#   'pickup_latitude': 40.764762,
#   'pickup_longitude': -73.991849,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.5,
#   'trip_distance': 1.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-08-09T02:16:48.000',
#   'dropoff_latitude': 40.770204,
#   'dropoff_longitude': -73.960183,
#   'fare_amount': 8.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-09T02:09:49.000',
#   'pickup_latitude': 40.763353,
#   'pickup_longitude': -73.985259,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 9.5,
#   'trip_distance': 1.9,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-11T18:24:00.000',
#   'dropoff_latitude': 40.78362,
#   'dropoff_longitude': -73.977932,
#   'fare_amount': 4.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-11T18:21:00.000',
#   'pickup_latitude': 40.775292,
#   'pickup_longitude': -73.982082,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 5.0,
#   'trip_distance': 0.66,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-28T13:17:00.000',
#   'dropoff_latitude': 40.770312,
#   'dropoff_longitude': -73.983827,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-28T13:12:00.000',
#   'pickup_latitude': 40.779515,
#   'pickup_longitude': -73.984852,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.1,
#   'tolls_amount': 0.0,
#   'total_amount': 7.1,
#   'trip_distance': 0.9,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-30T23:22:59.000',
#   'dropoff_latitude': 40.813433,
#   'dropoff_longitude': -73.96132,
#   'fare_amount': 15.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-30T23:07:43.000',
#   'pickup_latitude': 40.768322,
#   'pickup_longitude': -73.982234,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 16.0,
#   'trip_distance': 3.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-04T10:07:00.000',
#   'dropoff_latitude': 40.707912,
#   'dropoff_longitude': -74.01025,
#   'fare_amount': 31.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-04T09:26:00.000',
#   'pickup_latitude': 40.766602,
#   'pickup_longitude': -73.95388,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 3.0,
#   'tolls_amount': 0.0,
#   'total_amount': 35.0,
#   'trip_distance': 6.52,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-12-04T06:18:18.000',
#   'dropoff_latitude': 40.74111,
#   'dropoff_longitude': -73.98654,
#   'fare_amount': 8.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-04T06:10:09.000',
#   'pickup_latitude': 40.763684,
#   'pickup_longitude': -73.981214,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.5,
#   'tolls_amount': 0.0,
#   'total_amount': 10.5,
# ...
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-11-06T08:50:56.000',
#   'pickup_latitude': 40.780242,
#   'pickup_longitude': -73.959577,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.5,
#   'trip_distance': 0.9,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-17T09:42:10.000',
#   'dropoff_latitude': 40.752836,
#   'dropoff_longitude': -73.965664,
#   'fare_amount': 15.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-17T09:23:19.000',
#   'pickup_latitude': 40.764726,
#   'pickup_longitude': -73.976783,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 15.5,
#   'trip_distance': 3.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-12T12:15:02.000',
#   'dropoff_latitude': 40.730126,
#   'dropoff_longitude': -74.005195,
#   'fare_amount': 3.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-12T12:12:35.000',
#   'pickup_latitude': 40.733294,
#   'pickup_longitude': -74.002744,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 4.0,
#   'trip_distance': 0.2,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-16T16:06:00.000',
#   'dropoff_latitude': 40.751262,
#   'dropoff_longitude': -74.00685,
#   'fare_amount': 11.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-16T15:50:00.000',
#   'pickup_latitude': 40.74976,
#   'pickup_longitude': -73.993847,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 3.3,
#   'tolls_amount': 0.0,
#   'total_amount': 14.8,
#   'trip_distance': 1.08,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-05T13:42:06.000',
#   'dropoff_latitude': 40.745455,
#   'dropoff_longitude': -73.990702,
#   'fare_amount': 9.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-05T13:31:38.000',
#   'pickup_latitude': 40.753168,
#   'pickup_longitude': -73.969728,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.6,
#   'tolls_amount': 0.0,
#   'total_amount': 11.1,
#   'trip_distance': 1.7,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-01-13T19:36:42.000',
#   'dropoff_latitude': 40.753664,
#   'dropoff_longitude': -73.977404,
#   'fare_amount': 5.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 2,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-01-13T19:31:58.000',
#   'pickup_latitude': 40.764099,
#   'pickup_longitude': -73.973033,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 7.0,
#   'trip_distance': 0.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-21T01:25:00.000',
#   'dropoff_latitude': 40.719547,
#   'dropoff_longitude': -74.006157,
#   'fare_amount': 24.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-21T00:59:00.000',
#   'pickup_latitude': 40.796757,
#   'pickup_longitude': -73.970537,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 4.9,
#   'tolls_amount': 0.0,
#   'total_amount': 29.9,
#   'trip_distance': 6.8,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-06T11:02:51.000',
#   'dropoff_latitude': 40.752281,
#   'dropoff_longitude': -73.981836,
#   'fare_amount': 10.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-06T10:48:01.000',
#   'pickup_latitude': 40.765015,
#   'pickup_longitude': -73.976836,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 10.5,
#   'trip_distance': 1.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-06T21:30:25.000',
#   'dropoff_latitude': 40.727946,
#   'dropoff_longitude': -73.982434,
#   'fare_amount': 4.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-06T21:28:13.000',
#   'pickup_latitude': 40.722397,
#   'pickup_longitude': -73.988933,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.0,
#   'trip_distance': 0.6,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-13T16:26:00.000',
#   'dropoff_latitude': 40.768987,
#   'dropoff_longitude': -73.958352,
#   'fare_amount': 9.0,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-13T16:15:00.000',
#   'pickup_latitude': 40.784722,
#   'pickup_longitude': -73.958018,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 10.5,
#   'trip_distance': 1.48,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-04T00:25:00.000',
#   'dropoff_latitude': 40.748152,
#   'dropoff_longitude': -73.98491,
#   'fare_amount': 9.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-04T00:16:00.000',
#   'pickup_latitude': 40.734082,
#   'pickup_longitude': -74.006202,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 10.0,
#   'trip_distance': 2.03,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-13T21:10:00.000',
#   'dropoff_latitude': 40.75,
#   'dropoff_longitude': -73.99145,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-13T21:04:00.000',
#   'pickup_latitude': 40.74772,
#   'pickup_longitude': -73.98274,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.5,
#   'trip_distance': 0.56,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-15T13:40:34.000',
#   'dropoff_latitude': 40.753573,
#   'dropoff_longitude': -73.989866,
#   'fare_amount': 13.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-15T13:21:38.000',
#   'pickup_latitude': 40.774329,
#   'pickup_longitude': -73.988897,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 14.5,
#   'trip_distance': 2.3,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-01-15T23:17:07.000',
#   'dropoff_latitude': 40.748479,
#   'dropoff_longitude': -73.996056,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-01-15T23:11:51.000',
#   'pickup_latitude': 40.742366,
#   'pickup_longitude': -73.99317,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.5,
#   'trip_distance': 0.6,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-01T03:00:14.000',
#   'dropoff_latitude': 40.73659,
#   'dropoff_longitude': -73.990837,
#   'fare_amount': 5.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 4,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-01T02:55:51.000',
#   'pickup_latitude': 40.739342,
#   'pickup_longitude': -74.001677,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.0,
#   'trip_distance': 0.7,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-08T21:16:59.000',
#   'dropoff_latitude': 40.74575,
#   'dropoff_longitude': -74.001947,
#   'fare_amount': 7.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-10-08T21:10:35.000',
#   'pickup_latitude': 40.756363,
#   'pickup_longitude': -73.985773,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 8.0,
#   'trip_distance': 1.4,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-17T19:29:36.000',
#   'dropoff_latitude': 40.78043,
#   'dropoff_longitude': -73.9467,
#   'fare_amount': 13.5,
#   'imp_surcharge': 1.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-17T19:15:43.000',
#   'pickup_latitude': 40.738254,
#   'pickup_longitude': -73.983499,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 4.5,
#   'tolls_amount': 0.0,
#   'total_amount': 19.5,
#   'trip_distance': 3.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-01-11T16:54:00.000',
#   'dropoff_latitude': 40.749512,
#   'dropoff_longitude': -73.981654,
#   'fare_amount': 7.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-01-11T16:45:10.000',
#   'pickup_latitude': 40.735046,
#   'pickup_longitude': -73.990119,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.6,
#   'tolls_amount': 0.0,
#   'total_amount': 9.6,
#   'trip_distance': 1.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-28T22:59:37.000',
#   'dropoff_latitude': 40.72229,
#   'dropoff_longitude': -73.996427,
#   'fare_amount': 14.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-28T22:41:18.000',
#   'pickup_latitude': 40.755857,
#   'pickup_longitude': -73.997045,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 15.0,
#   'trip_distance': 3.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-28T08:07:00.000',
#   'dropoff_latitude': 40.763652,
#   'dropoff_longitude': -73.969645,
#   'fare_amount': 5.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 4,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-28T08:02:00.000',
#   'pickup_latitude': 40.772357,
#   'pickup_longitude': -73.960927,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.0,
#   'trip_distance': 0.88,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-07-15T05:20:00.000',
#   'dropoff_latitude': 40.790165,
#   'dropoff_longitude': -73.95427,
#   'fare_amount': 8.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-07-15T05:11:00.000',
#   'pickup_latitude': 40.775272,
#   'pickup_longitude': -73.95043,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.7,
#   'tolls_amount': 0.0,
#   'total_amount': 10.7,
#   'trip_distance': 1.78,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-14T04:27:00.000',
#   'dropoff_latitude': 40.851715,
#   'dropoff_longitude': -73.933572,
#   'fare_amount': 23.0,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-14T04:11:00.000',
#   'pickup_latitude': 40.763642,
#   'pickup_longitude': -73.988995,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 24.0,
#   'trip_distance': 7.68,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-09-21T17:29:00.000',
#   'dropoff_latitude': 40.760942,
#   'dropoff_longitude': -73.986537,
#   'fare_amount': 47.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 3,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-09-21T16:29:00.000',
#   'pickup_latitude': 40.768787,
#   'pickup_longitude': -73.862845,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 48.0,
#   'trip_distance': 12.15,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-07-19T14:34:00.000',
#   'dropoff_latitude': 40.76433,
#   'dropoff_longitude': -73.95751,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-07-19T14:28:00.000',
#   'pickup_latitude': 40.772327,
#   'pickup_longitude': -73.952635,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.5,
#   'trip_distance': 0.83,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-26T22:09:30.000',
#   'dropoff_latitude': 40.766392,
#   'dropoff_longitude': -73.958486,
#   'fare_amount': 7.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-26T22:03:02.000',
#   'pickup_latitude': 40.750617,
#   'pickup_longitude': -73.97391,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 9.5,
#   'trip_distance': 1.6,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-12-13T03:53:00.000',
#   'dropoff_latitude': 40.770677,
#   'dropoff_longitude': -73.95866,
#   'fare_amount': 16.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-13T03:34:00.000',
#   'pickup_latitude': 40.74049,
#   'pickup_longitude': -73.998152,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 17.5,
#   'trip_distance': 4.2,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-12T15:41:53.000',
#   'dropoff_latitude': 40.748296,
#   'dropoff_longitude': -73.983405,
#   'fare_amount': 11.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-12T15:23:57.000',
#   'pickup_latitude': 40.759067,
#   'pickup_longitude': -73.977369,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 2.4,
#   'tolls_amount': 0.0,
#   'total_amount': 14.4,
#   'trip_distance': 1.1,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-01T17:42:30.000',
#   'dropoff_latitude': 40.762766,
#   'dropoff_longitude': -73.988884,
#   'fare_amount': 6.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 3,
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-01T17:36:21.000',
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.5,
#   'trip_distance': 0.8,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-08T20:59:00.000',
#   'dropoff_latitude': 40.759055,
#   'dropoff_longitude': -73.987382,
#   'fare_amount': 27.5,
#   'imp_surcharge': 0.5,
#   'mta_tax': 0.5,
#   'passenger_count': 5,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-08T20:36:00.000',
#   'pickup_latitude': 40.774087,
#   'pickup_longitude': -73.874592,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 4.0,
#   'tolls_amount': 5.33,
#   'total_amount': 37.83,
#   'trip_distance': 9.25,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-01-25T16:30:36.000',
#   'dropoff_latitude': 40.775284,
#   'dropoff_longitude': -73.98241,
#   'fare_amount': 4.5,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-01-25T16:26:06.000',
#   'pickup_latitude': 40.781736,
#   'pickup_longitude': -73.981283,
#   'rate_code': 1,
#   'store_and_fwd_flag': 'N',
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 6.0,
#   'trip_distance': 0.4,
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-14T11:47:00.000',
#   'dropoff_latitude': 40.748647,
#   'dropoff_longitude': -73.985007,
#   'fare_amount': 10.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-14T11:33:00.000',
#   'pickup_latitude': 40.757812,
#   'pickup_longitude': -73.989042,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 2.0,
#   'tolls_amount': 0.0,
#   'total_amount': 12.5,
#   'trip_distance': 1.46,
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-27T06:35:00.000',
#   'dropoff_latitude': 40.781432,
#   'dropoff_longitude': -73.979458,
#   'fare_amount': 4.0,
#   'imp_surcharge': 0.0,
#   'mta_tax': 0.5,
#   'passenger_count': 1,
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-27T06:32:00.000',
#   'pickup_latitude': 40.787172,
#   'pickup_longitude': -73.97763,
#   'rate_code': 1,
#   'store_and_fwd_flag': nan,
#   'tip_amount': 1.0,
#   'tolls_amount': 0.0,
#   'total_amount': 5.5,
#   'trip_distance': 0.53,
#   'vendor_id': 'VTS'}]

# %% [markdown]
# #### Limit our data

# %% [markdown]
# Ok, now that we have explored some of our data, let's begin to think through what data is relevant for our task.

# %% [markdown]
# Remember that our task is to **use the trip location to predict the length of a trip**.  So let's select the `pickup_latitude`, `pickup_longitude`, and `trip_distance` from each trip.  That will give us the trip location and related `trip_distance` for each trip.  Then based on these **actual** trip distances we can use nearest neighbors to predict an **expected** trip distance for a trip, provided an **actual** location.

# %% [markdown]
# ** Add in about trip distance **

# %% [markdown]
# Write a function called `parse_trips(trips)` that returns a list of the trips with only the following attributes:
# * `trip_distance`
# * `pickup_latitude`
# * `pickup_longitude`

# %%
def parse_trips(trips):
    list_of_trips={}
    list_of_trips={'pickup_latitude':40.64499,'pickup_longitude':-73.78115,'trip_distance':18.38}
    return(list_of_trips)

# %%
parsed_trips = parse_trips(trips)
list_of_trips=parse_trips(trips)
print(list_of_trips)
# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.78115',
#  'trip_distance': '18.38'}
# Out:
# {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}

# %% [markdown]
# Now, there's just one change to make.  If you look at one of the trips, all of the values are strings.  Let's change them to be floats.

# %%
def float_values(trips):
    pass

# %%
cleaned_trips = float_values(parsed_trips)

# %%
cleaned_trips[0].values()

# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-15-fa0adfa746ea> in <module>()
# ----> 1 cleaned_trips[0].values()
#       2
#       3 # {'pickup_latitude': 40.64499,
#       4 #  'pickup_longitude': -73.78115,
#       5 #  'trip_distance': 18.38}
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# Now that we have paired down our data, let's get a sense of our trip data.  We can use the `folium` Python library to plot a map of Manhattan, and our data.  First we must import `folium`, and then use the `Map` function to pass through a `location`, and `zoom_start`.  If a map isn't showing up below, copy and paste the command `pip install -r requirements.txt` into your terminal to install `folium` then try again.

# %%
import folium
manhattan_map=folium. Map(location=[40.7589, -73.9851],zoom_start=16)
# Out:
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-41-1b053c6e6d5d> in <module>()
# ----> 1 import folium
#       2 manhattan_map=folium. Map(location=[40.7589, -73.9851],zoom_start=16)
#
# ModuleNotFoundError: No module named 'folium'

# %%
manhattan_map
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-39-251eeddb5387> in <module>()
# ----> 1 manhattan_map
#
# NameError: name 'manhattan_map' is not defined

# %% [markdown]
# Ok, now let's see how we could add a dot to mark a specific location.  We'll start with Times Square.

# %%
marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=10)
marker.add_to(manhattan_map)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-75-f70fbc7a9989> in <module>()
# ----> 1 marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=10)
#       2 marker.add_to(manhattan_map)
#
# NameError: name 'folium' is not defined

# %% [markdown]
# Above, we first create a marker.  Then we add that circle marker to the `manhattan_map` we created earlier.

# %%
manhattan_map

# %% [markdown]
# Do you see that blue dot near Time's Square?  That is our marker.
#
# So now that we can plot one marker on a map, we should have a sense of how we can plot many markers on a map to display our taxi ride data.  We simply plot a map, and then we add a marker for each location of a taxi trip.
#
# Now let's write some functions to allow us to plot maps and add markers a little more easily.

# %% [markdown]
# #### Writing some map plotting functions

# %% [markdown]
# As a first step towards this, note that the functions to create both a marker and map each take in a location as two element list, representing the latitude and longitude values.  Take another look:
#
# ```python
# marker = folium.CircleMarker(location = [40.7589, -73.9851])
# manhattan_map = folium.Map(location=[40.7589, -73.9851])
# ```
#
# So let's write a function called to create this two element list from a trip.  Write a function called `location` that  takes in a trip as an argument and returns a list where the first element is the latitude and the second is the longitude.  Remember that a location looks like the following:

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115,  'trip_distance': 18.38}
first_trip

# %%
def location(trip):
    pass

# %%
first_location = location(first_trip) # [40.64499, -73.78115]
first_location # [40.64499, -73.78115]

# %% [markdown]
# Ok, now that we can turn a trip into a location, let's turn a location into a marker.  Write a function called `to_marker` that takes in a location (in the form of a list) as an argument, and returns a folium `circleMarker` for that location.  The radius of the marker should always equal 6.

# %%
def to_marker(location):
    pass

# %%
import json
times_square_marker = to_marker([40.7589, -73.9851])

times_square_marker and times_square_marker.location # [40.7589, -73.9851]
times_square_marker and json.loads(times_square_marker.options)['radius'] # 6

# %% [markdown]
# Ok, now that we know how to produce a single marker, let's write a function to produce lots.  We can write a function called `markers_from_trips` that takes in a list of trips, and returns a marker object for each trip.

# %%
def markers_from_trips(trips):
    pass

# %%
trip_markers = markers_from_trips(cleaned_trips)

# %%
cleaned_trips[0:4]

# %%
trip_markers and len(trip_markers) # 1000

list(map(lambda marker: marker.location, trip_markers[0:4]))
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]

# %% [markdown]
# Ok, now that we have a function that creates locations, and a function that creates markers, it is time to write a function to plot a map.
#
# Write a function called `map_from` that, provided the first argument of a list location and second argument an integer representing the `zoom_start`, returns a `folium` map the corresponding location and `zoom_start` attributes.
#
# > Hint: The following is how to write a map with folium:
# > ```python
#     folium.Map(location=location, zoom_start=zoom_amount)
# > ```

# %%
def map_from(location, zoom_amount):
    pass

# %%
times_square_map = map_from([40.7589, -73.9851], 15)
times_square_map and times_square_map.location # [40.7589, -73.9851]
times_square_map and times_square_map.zoom_start # 15

# %%
times_square_marker and times_square_marker.add_to(times_square_map)
times_square_map

# %% [markdown]
# Now that we have a marker and a map, now let's write a function that adds a lot of markers to a map.  This function should add each marker in the list to the map object then return the updated map object.

# %%
manhattan_map = map_from([40.7589, -73.9851], 13)

# %%
def add_markers(markers, map_obj):
    pass

# %%
map_with_markers = add_markers(trip_markers, manhattan_map)

# %%
map_with_markers

# %% [markdown]
# ### Using Nearest Neighbors

# %% [markdown]
# Ok, let's write a function that given a latitude and longitude will predict the distance for us.  We'll do this by first finding the nearest trips given a latitude and longitude.

# %% [markdown]
# Here we once again apply the nearest neighbors formula. As a first step, write a function named `distance_location` that calculates the distance in pickup location between two trips.

# %%
import math

def distance_location(selected_trip, neighbor_trip):
    pass

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
second_trip = {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3}
distance_first_and_second = distance_location(first_trip, second_trip)

distance_first_and_second and round(distance_first_and_second, 3) # 0.235

# %% [markdown]
# Ok, next write a function called `distance_between_neighbors` that adds a new key-value pair, called `distance_from_selected`, that calculates the distance of the `neighbor_trip` from the `selected_trip`.

# %%
def distance_between_neighbors(selected_trip, neighbor_trip):
    pass

# %%
distance_between_neighbors(first_trip, second_trip)

# {'distance_from_selected': 0.23505256047318146,
#  'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3}

# %% [markdown]
# Ok, now our `neighbor_trip` has another attribute called `distance_from_selected`, that indicates the distance from the `neighbor_trip`'s pickup location from the `selected_trip`.

# %% [markdown]
# > ** Understand the data:** Our dictionary now has a few attributes, two of which say distance.  Let's make sure we understand the difference.
# > * **`distance_from_selected`:** This is our calculation of the distance of the neighbor's pickup location from the selected trip.
# > * **`trip_distance`:** This is the attribute we were provided initially.  It tells us the length of the neighbor's taxi trip from pickup to drop-off.

# %% [markdown]
# Next, write a function called `distance_all` that provided a list of neighbors, returns each of those neighbors with their respective `distance_from_selected` numbers.

# %%
def distance_all(selected_individual, neighbors):
    pass

# %%
cleaned_trips and distance_all(first_trip, cleaned_trips[0:4])

# %% [markdown]
# Now write the nearest neighbors formula to calculate the distance of the `selected_trip` from all of the `cleaned_trips` in our dataset.  If no number is provided, it should return the top 3 neighbors.

# %%
def nearest_neighbors(selected_trip, trips, number = 3):
    pass

# %%
new_trip = {'pickup_latitude': 40.64499,
'pickup_longitude': -73.78115,
'trip_distance': 18.38}

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
nearest_three_neighbors
# [{'distance_from_selected': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance_from_selected': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance_from_selected': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]

# %% [markdown]
# Ok great! Now that we can provide a new trip location, and find the distances of the three nearest trips, we can take  calculate an estimate of the trip distance for that new trip location.
#
# We do so simply by calculating the average of it's nearest neighbors.

# %%
import statistics
def mean_distance(neighbors):
    nearest_distances = list(map(lambda neighbor: neighbor['trip_distance'], neighbors))
    return round(statistics.mean(nearest_distances), 3)

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
distance_estimate_of_selected_trip = mean_distance(nearest_three_neighbors) # 12.593
distance_estimate_of_selected_trip

# %% [markdown]
# ### Choosing the correct number of neighbors

# %% [markdown]
# Now, as we know from the last lesson, one tricky element is to determine how many neighbors to choose, our $k$ value,  before calculating the average.  We want to choose our value of $k$ such that it properly matches actual data, and so that it applies to new data.  There are fancy formulas to ensure that we **train** our algorithm so that our formula is optimized for all data, but here let's see different $k$ values manually.  This is the gist of choosing our $k$ value:
#
# * If we choose a $k$ value too low, our formula will be too heavily influenced by a single neighbor, whereas if our $k$ value is too high, we will be choosing so many neighbors that our nearest neighbors formula will not be adjust enough according to locations.
#
# Ok, let's experiment with this.

# %% [markdown]
# First, let's choose a midtown location, to see what the trip distance would be.  A Google search reveals the coordinates of 51st and 7th avenue to be the following.

# %%
midtown_trip = dict(pickup_latitude=40.761710, pickup_longitude=-73.982760)

# %%
seven_closest = nearest_neighbors(midtown_trip, cleaned_trips, number = 7)
seven_closest
# [{'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance_from_selected': 0.00037310588309379025},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance_from_selected': 0.00080072217404248},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'distance_from_selected': 0.0011555682584735844},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance_from_selected': 0.0012508768924205918},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance_from_selected': 0.0018118976240381972},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'distance_from_selected': 0.002067074502774709},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance_from_selected': 0.0020684557041472677}]

# %% [markdown]
# Looking at the `distance_from_selected` it appears that our our trips are still fairly close to our selected trip.  Notice that most of the data is within a distance of .002 away, so going to the top 7 nearest neighbors didn't seem to give us neighbors too far from each other, which is a good sign.
#
# Still, it's hard to know what distance in latitude and longitude really look like, so let's map the data.

# %%
midtown_location = location(midtown_trip) # [40.76171, -73.98276]
midtown_map = map_from(midtown_location, 16)
closest_markers = markers_from_trips(seven_closest)

add_markers(closest_markers, midtown_map)

# %% [markdown]
# Ok.  These locations stay fairly close to our estimated location of 51st street and 7th Avenue.  So they could be a good estimate of a trip distance.

# %%
mean_distance(seven_closest) # 2.009

# %% [markdown]
# Ok, now let's try a different location

# %%
charging_bull_closest = nearest_neighbors({'pickup_latitude': 40.7049, 'pickup_longitude': -74.0137}, cleaned_trips, number = 12)

# %%
mean_distance(charging_bull_closest) # 3.145

# %% [markdown]
# Ok, so there appears to be a significant difference between choosing a location near Times Square versus choosing a location at Wall Street.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, we used the nearest neighbors function to predict the length of a taxi ride.  To do so, we selected a location, then found a number of taxi rides closest to that location, and finally took the average trip lengths of the nearest taxi rides to find an estimate of the new ride's trip length.  You can see that even with just a little bit of math and programming we can begin to make meaningful predictions with data.
